# %%
import csv

# %%
json_data_list = [
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "APBPS8704D",
            "full_name": "MOHAMMAD SALIM",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135470850,
        "transaction_id": "d3ad7ee8-c5bc-4309-be17-27df8dce9a49"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAOPJ7950N",
            "full_name": "DILIP TARACHAND JAIN",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135510542,
        "transaction_id": "474cec8d-0fdc-41d0-a91a-f051ccc3e00d"
    },
    {
    "code": 200,
    "data": {
        "@entity": "pan",
        "pan": "AAHFB0316M",
        "full_name": "BALAJI ENTERPRISES",
        "status": "VALID",
        "category": "Firm"
    },
    "timestamp": 1697135538051,
    "transaction_id": "917d0b0b-2393-452e-87d3-2d8c4cb80478"
    },
    {
    "code": 200,
    "data": {
        "@entity": "pan",
        "pan": "ACGPS5752F",
        "full_name": "SATISH J SETHIA",
        "status": "VALID",
        "category": "Individual"
    },
    "timestamp": 1697135592371,
    "transaction_id": "6434884a-ab5a-4268-85c1-bc2aa03b5062"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AABCJ2488H",
            "full_name": "JAI BALAJI JYOTI STEELS LIMITED",
            "status": "VALID",
            "category": "Company"
        },
        "timestamp": 1697115013210,
        "transaction_id": "96174893-21d5-4600-b4bf-6bf3b14aac4a"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AFXPG8926R",
            "full_name": "ANIL KUMAR GUPTA",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697115143263,
        "transaction_id": "8efd660b-4522-4555-9ea7-166dc6b97090"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAACN1660Q",
            "full_name": "NYKA STEELS PRIVATE LIMITED",
            "status": "VALID",
            "category": "Company"
        },
        "timestamp": 1697114798565,
        "transaction_id": "30e96547-7f77-4a90-964e-86741fd3cfac"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAACL6442L",
            "full_name": "ULTRATECH CEMENT LIMITED",
            "status": "VALID",
            "category": "Company"
        },
        "timestamp": 1697114985108,
        "transaction_id": "7d10c68b-3ab6-4ffe-a688-f6853addca94"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAKFA7257R",
            "full_name": "AMAR ROLLER FLOUR MILLS",
            "status": "VALID",
            "category": "Firm"
        },
        "timestamp": 1697135734205,
        "transaction_id": "df6a7dd6-b8f1-482e-9586-b797cef84a41"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "ALPPK1937Q",
            "full_name": "BUDH SEN KESARWANI",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135782187,
        "transaction_id": "a60d95f2-5304-4674-8a78-d30cae4628f6"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAQFA8753N",
            "full_name": "AMRITSARIA MAL STONE CRUSHER",
            "status": "VALID",
            "category": "Firm"
        },
        "timestamp": 1697135810940,
        "transaction_id": "6d5f60b7-9c9a-4f83-91b8-2f500cdb8940"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "BIMPA2958Q",
            "full_name": "RAVI B AGRAWAL",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135844626,
        "transaction_id": "1753f2f3-da26-48d1-8f88-f1843c966ae9"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAJCS7300P",
            "full_name": "SWASTIKA STRUCTURAL PRODUCTS PRIVATE LIMITED",
            "status": "VALID",
            "category": "Company"
        },
        "timestamp": 1697135876364,
        "transaction_id": "5985e0d9-30eb-4634-ab1f-42eb69e7c292"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AAPFD1084Q",
            "full_name": "DGB OVERSEAS",
            "status": "VALID",
            "category": "Firm"
        },
        "timestamp": 1697135901629,
        "transaction_id": "19d2f91d-9311-428e-9cad-b3f78cd3927a"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "EWKPK0411D",
            "full_name": "SHABNAM BEGAM YUNUS KHAN",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135927242,
        "transaction_id": "50392b98-3bb0-4b59-af44-9daeb6fb84ea"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "AABCA5165G",
            "full_name": "ADEPT FLUIDYNE PRIVATE LIMITED",
            "status": "VALID",
            "category": "Company"
        },
        "timestamp": 1697135956740,
        "transaction_id": "bd8a77a1-3056-4b1d-a580-86734b98217f"
    },
    {
        "code": 200,
        "data": {
            "@entity": "pan",
            "pan": "ADYPR8512K",
            "full_name": "HARBINDER SINGH RAI",
            "status": "VALID",
            "category": "Individual"
        },
        "timestamp": 1697135981219,
        "transaction_id": "edbd5c21-311d-4242-97a7-dbfa0935f3db"
    }
]

# Writing to CSV file
csv_file_path = "output.csv"

with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)

    # Write header
    writer.writerow(["code", "data_entity", "pan", "full_name", "status", "category", "timestamp", "transaction_id"])

    # Write data
    for data_item in json_data_list:
        code = data_item["code"]
        data_entity = data_item["data"]["@entity"]
        pan = data_item["data"]["pan"]
        full_name = data_item["data"]["full_name"]
        status = data_item["data"]["status"]
        category = data_item["data"]["category"]
        timestamp = data_item["timestamp"]
        transaction_id = data_item["transaction_id"]

        writer.writerow([code, data_entity, pan, full_name, status, category, timestamp, transaction_id])

print(f"CSV file '{csv_file_path}' has been created.")
# Out:
# CSV file 'output.csv' has been created.
